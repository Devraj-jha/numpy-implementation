# %%
import numpy as np

# %%
list = [1,2,3,4,5]

num_array = np.array([1,2,3,4,4])

print("operation on python list : " , [x + 10 for x in list])


print("num arry", num_array + 10)
print("python list", (list))
# Out:
# operation on python list :  [11, 12, 13, 14, 15]
# num arry [11 12 13 14 14]
# python list [1, 2, 3, 4, 5]

# %%
import time 

size = 100000000

list = list(range(size))

num = np.arange(size)

print("--- performance test")
